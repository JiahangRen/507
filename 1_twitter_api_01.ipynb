# %%
# twitter api doc API reference index
# https://developer.twitter.com/en/docs/api-reference-index

# %%
import platform
import requests

# 12 nba stars twitter 
nba_star = ["KDTrey5", "JHarden13", "russwest44", "CP3", "Giannis_An34", 
       "Dame_Lillard", "TheTraeYoung", "DevinBook", "ZachLaVine",
       "StephenCurry30", "KlayThompson", "DeMar_DeRozan"]

token = "AAAAAAAAAAAAAAAAAAAAANTvWAEAAAAAxV1p50rhTxTNIwscXWaR6qcDoNg%3D7CdaQpbNovUrSLL5V3dyZGx62zLDkBeW5RzGvqBn77rHfTImE4"


def get_user_info(username):
  url = f"https://api.twitter.com/2/users/by/username/{username}"
  headers = {'Authorization': f'Bearer {token}'}
  params = {"user.fields": "description,url,location"} # 
  response = requests.get(url, headers=headers, params=params)
  return response.json()

username = "KDTrey5"
get_user_info(username)
# Out:
# {'data': {'description': 'IM ME, I DO ME, AND I CHILL. @35ventures @boardroom',
#   'id': '35936474',
#   'location': 'At the crib dog',
#   'name': 'Kevin Durant',
#   'url': 'https://t.co/gf7hhjZ4WY',
#   'username': 'KDTrey5'}}

# %%
import pandas as pd 
user_data = {"user_id": [], "name": [], "username": [],
        "description": [], "url": [], "location": []}
             
for i in nba_star:
  x = get_user_info(i)["data"]
  user_data["user_id"].append(x["id"])
  user_data["name"].append(x["name"])
  user_data["username"].append(x["username"])

  user_data["description"].append(x["description"] if "description" in x else None)
  user_data["url"].append(x["url"] if "url" in x else None)
  user_data["location"].append(x["location"] if "location" in x else None)

user_df = pd.DataFrame(user_data)
user_df
# Out:
#        user_id                   name        username  \
# 0     35936474           Kevin Durant         KDTrey5
# 1     50811932           James Harden       JHarden13
# 2     35982046      Russell Westbrook      russwest44
# 3     53853197             Chris Paul             CP3
# 4   2279776304  Giannis Antetokounmpo    Giannis_An34
# 5    267425142         Damian Lillard    Dame_Lillard
# 6   2842841126             Trae Young    TheTraeYoung
# 7    237073728                   Book       DevinBook
# 8    405205681            Zach LaVine      ZachLaVine
# 9     42562446          Stephen Curry  StephenCurry30
# 10  1703636814          klay thompson    KlayThompson
# 11    43658360          DeMar DeRozan   DeMar_DeRozan
#
#                                           description  \
# 0   IM ME, I DO ME, AND I CHILL. @35ventures @boar...
# 1               NBA Player for the Philadelphia 76ers
# 2                                           WHY NOT ?
# 3                      💚: @chrispaulfamfdn 🎥: @ohhdip
# 4   "It's beauty in the struggle, ugliness in the ...
# 5   They say the truth shall come to the light...s...
# 6   Point Guard for the Atlanta Hawks  Trae Young ...
# 7
# 8
# 9   Believer. Husband 2 @ayeshacurry, father to Ri...
# 10              Shooting guard, Golden State Warriors
# 11                        Born and raised in Compton.
#
#                         url          location
# 0   https://t.co/gf7hhjZ4WY   At the crib dog
# 1   https://t.co/4lMKEywgN4  Philadelphia, PA
# 2   https://t.co/da8rU1I43X   Los Angeles, CA
# 3                                        None
# 4                                Milwaukee WI
# 5   https://t.co/Gjrq26STv9              None
# 6                                 Atlanta, GA
# 7                                        None
# 8                                        None
# 9   https://t.co/GoKze52y5r         Worldwide
# 10  https://t.co/E66x0gj9Yu              None
# 11  https://t.co/HVeqXr6NUY              None

# %%
from google.colab import files
user_df.to_csv("user_info.csv")

files.download("user_info.csv")

# %% [markdown]
# # Get followers. Maybe later

# %%
# doc max results 100 need turn page。
# https://developer.twitter.com/en/docs/twitter-api/users/follows/api-reference/get-users-id-followers

# def get_followers(user_id):
#   url = f"https://api.twitter.com/2/users/{user_id}/followers"
#   headers = {'Authorization': f'Bearer {token}'}
#   params = {"max_results": 100}
#   response = requests.get(url, headers=headers)
#   return response.json()

# get_followers("43658360")

# %% [markdown]
# # Get following

# %%
# doc max results 100  
# https://developer.twitter.com/en/docs/twitter-api/users/follows/api-reference/get-users-id-followers

def get_following(user_id):
  url = f"https://api.twitter.com/2/users/{user_id}/following"
  headers = {'Authorization': f'Bearer {token}'}
  params = {"max_results": 100}
  response = requests.get(url, headers=headers, params=params)
  return response.json()

# get_following("35936474")

# %%
following_dic = {"user_id": [], "following_user_id": [], "following_name": [], "following_username": []}
for i in user_df["user_id"]:
  for j in get_following(i)["data"]:
    following_dic["user_id"].append(i)
    following_dic["following_user_id"].append(j["id"])
    following_dic["following_name"].append(j["name"])
    following_dic["following_username"].append(j["username"])


following_df = pd.DataFrame(following_dic)
following_df
# Out:
#        user_id    following_user_id      following_name following_username
# 0     35936474  1159492947055972353              Austin            Amalk04
# 1     35936474             42330201             Rae 🧡💚💛       Mixed_Girl_5
# 2     35936474  1491845999769313288                Dre🐍    SirWaveyForever
# 3     35936474            314630666     Leonard Ellerbe           LEllerbe
# 4     35936474             44771048          Ron Conway          RonConway
# ...        ...                  ...                 ...                ...
# 1102  43658360            555393138     Harrison Barnes            hbarnes
# 1103  43658360             50323173  Adrian Wojnarowski            wojespn
# 1104  43658360            267425142      Damian Lillard       Dame_Lillard
# 1105  43658360            349719397            JR Smith     TheRealJRSmith
# 1106  43658360            112237031            MASTER P      MasterPMiller
#
# [1107 rows x 4 columns]

# %%
from google.colab import files
user_df.to_csv("user_with_follwing.csv", index=False)

files.download("user_with_follwing.csv")

# %% [markdown]
# # Get 100 tweets for each user

# %%
# get 100 tweets
def get_tweets(user_id):
  url = f"https://api.twitter.com/2/users/{user_id}/tweets"
  headers = {'Authorization': f'Bearer {token}'}
  params = {"max_results": 100}
  response = requests.get(url, headers=headers, params=params)
  return response.json()

get_tweets("35936474")
# Out:
# {'data': [{'id': '1512849149091274756',
#    'text': 'S/O Dwight Powell, made that Achilles recovery look like nothing. Love'},
#   {'id': '1512658691207712774', 'text': 'U get it https://t.co/GycZwrnxfm'},
#   {'id': '1512647516008988675',
#    'text': 'No foul??????? https://t.co/PBseqE2sEt'},
#   {'id': '1512471596291743744',
#    'text': '@mustseetb_ @jj_redick Yep. The slots'},
#   {'id': '1512155746615672844',
#    'text': 'Preciate dat dere boiiii https://t.co/9DJB56ZRa3'},
#   {'id': '1511748090457473028',
#    'text': 'RT @boardroom: On a new crossover episode of The ETCs X @OldManAndThree, the guys discuss:\n\n🎙 Clippers/Thunder series in 2014\n🎙 KD and @jj_…'},
#   {'id': '1511748078684061714',
#    'text': 'RT @boardroom: “Yeah, I knew it was. It’s weird that you can feel that type of stuff … As soon as I stepped on it, I’m like ‘Damn.’”\n\n—@KDT…'},
#   {'id': '1511708622530789382',
#    'text': "RT @talter: ep 108 of the @OldManAndThree live now on all platforms. a ETC's crossover with the OG easy money sniper @KDTrey5 and the great…"},
#   {'id': '1511466954015625219',
#    'text': '@DaKidGowie Bro is VEXED. Don’t even trip, bill is the only one who feels this way.'},
#   {'id': '1511377674895249416', 'text': 'RT @boardroom: 🔥🔥'},
#   {'id': '1511360849348374535',
#    'text': 'Lock in gods https://t.co/HQrvDTD4El'},
#   {'id': '1511340762558042119', 'text': '@SoThatsSlim 😂'},
#   {'id': '1511330685562376201',
#    'text': 'Damn steve. Got ya ass https://t.co/oyZY5uPCKx'},
#   {'id': '1510834333027811331', 'text': '@donstanlo U welcome gang'},
#   {'id': '1509997226143199235', 'text': 'My brothers https://t.co/jz4rDKL7OP'},
#   {'id': '1509995758895968259',
#    'text': '@YoungRaww95 @joechivs1 Unfortunately, for you, it’s out of your control lol'},
#   {'id': '1509994830776131584',
#    'text': '@joechivs1 I really don’t see a problem with what I said…'},
#   {'id': '1509754147201069092',
#    'text': '@Tjonesonthenba I’m not from New York champ'},
#   {'id': '1509735271474110466',
#    'text': 'A god. Just like you are but u rather be a peasant https://t.co/ZSmUmhGl1D'},
#   {'id': '1509726274872348672',
#    'text': 'Don’t feel bad for the god. Life has been incredible little Nicky 😁 https://t.co/fZ0jrPHXHm'},
#   {'id': '1509340189059166211',
#    'text': 'This is embarrassing https://t.co/eGA8epyrSj'},
#   {'id': '1509308535951216643',
#    'text': 'I beam up. Never off beam https://t.co/73cfZnmSBV'},
#   {'id': '1509156649482833923',
#    'text': 'Thee American Player https://t.co/S5434LJkyq'},
#   {'id': '1509039992051490818',
#    'text': 'Me and my cousin Tia coding this in 03 https://t.co/lD43UUjzCH https://t.co/3Psdd6yTBT'},
#   {'id': '1508499567846776843',
#    'text': 'RT @boardroom: Final day to enter! \n\nEnter to win a KD-curated "Game Recognize Game" @nbatopshot pack by hitting the link below and signing…'},
#   {'id': '1507439262857367564', 'text': 'Incredible https://t.co/Y9WxhEqNGd'},
#   {'id': '1506844460415602691', 'text': '#talkin https://t.co/CYdib2Muhj'},
#   {'id': '1506686842166554624',
#    'text': 'New ETCs episode up today! https://t.co/SGuRvBWLDF'},
#   {'id': '1505598942771396611', 'text': 'Yessir https://t.co/JixnSQO050'},
#   {'id': '1504807747925254169',
#    'text': 'RT @boardroom: .@Weedmaps is making sure that you can get your green-related content beyond St. Patrick’s Day.\n\nThat’s right, "Strains Madn…'},
#   {'id': '1504807648344121351',
#    'text': 'Really creative campaign from the team at @weedmaps https://t.co/LmICJidQtd'},
#   {'id': '1504299752950837248',
#    'text': 'Damn smh https://t.co/OsmWTruu4v https://t.co/jPjI6mAjzR'},
#   {'id': '1503972312781144065',
#    'text': 'ATTN: Eleven taught another class tonight. Please review the film if you haven’t…'},
#   {'id': '1503532913685676033',
#    'text': 'Aye jokic. That was a DIME. https://t.co/KuxwwPYeAv'},
#   {'id': '1503418174112505866',
#    'text': 'RT @boardroom: We’re giving away 35 KD-curated “Game Recognize Game” @nbatopshot packs to celebrate some of the NBA’s best moments from thi…'},
#   {'id': '1502486692455927808',
#    'text': 'https://t.co/Z5UfmvnsKn https://t.co/K9EE3UMKNN'},
#   {'id': '1502151751666786307',
#    'text': 'Stove God one of the best rappers in the world. Appreciate that man'},
#   {'id': '1501978905451941888',
#    'text': 'RT @MLS: This is a landmark moment – in sports history, in Civil Rights history, in American history.\n\nIn collaboration with @BPCMLS, @Bern…'},
#   {'id': '1501927239717466115',
#    'text': 'RT @boardroom: EXCLUSIVE: Only 3% of the $147.6 billion in U.S. venture capital went to Black-founded companies in 2020.\n\n@michaelb4jordan…'},
#   {'id': '1501676709585772553',
#    'text': 'If Allah shine, kutter gon shine, it’s mathematical'},
#   {'id': '1501597323536830475',
#    'text': 'Back in biz with a new ETCs https://t.co/cip6LhqpPm'},
#   {'id': '1501397030714945538',
#    'text': '@TheMisterMarcus Lol I had to put u on the Jumbotron real quick. 😂'},
#   {'id': '1501395665871683585',
#    'text': 'When them parlays don’t hit. This is for years of slander from nba fans, im grateful I have this much power now. 😁 https://t.co/RSFaryY7Sc'},
#   {'id': '1500862223601778697',
#    'text': 'RT @RonConway: I stand with Ukraine. Join me in supporting this @gofundmedotorg fundraiser supporting the work of @Flexport and @airbnb—two…'},
#   {'id': '1500240012801150980',
#    'text': 'RT @BallsackSports: Today we will focus on the dangers of misinform in the media, and stress the importance of media literacy. \n\nSocial med…'},
#   {'id': '1498444159417565186',
#    'text': 'RT @ABCGMA3: #MoneyMonday: @RichKleiman, co-founder of "Thirty Five Ventures and Boardroom," breaks down what you need to know about crypto…'},
#   {'id': '1497648605162729474',
#    'text': 'RT @bansky: Some weekend podcast listening for you…\n\nThis week on #TheETCs I was joined by the Head of Sports at Twitter… my guy @TJay\n\nWe…'},
#   {'id': '1496644635904589827',
#    'text': 'Good looks @boardroom @weedmaps https://t.co/DGMLWuskUV'},
#   {'id': '1495441649169747968', 'text': '@waldorfsfinest 😂'},
#   {'id': '1495246303424663556',
#    'text': 'Me after a basic one hand https://t.co/5zYuMFh3B2 https://t.co/opMBMsMWaI'},
#   {'id': '1495122057654411266',
#    'text': '@SlayYoung23 I think my move kept others up at night.'},
#   {'id': '1495109775318822915',
#    'text': '@waldorfsfinest @Krisplashed Stay in denial if that helps u'},
#   {'id': '1495068335565848587',
#    'text': 'RT @richkleiman: Thanks to @Adweek for the feature on what we’ve built at @35Ventures @boardroom https://t.co/13dfdaqFu5 https://t.co/xRo8k…'},
#   {'id': '1495045921268248576', 'text': 'A word https://t.co/78Dpk5taWj'},
#   {'id': '1495045100392620035',
#    'text': 'https://t.co/INccQIe8Ii https://t.co/hh6UEoLqmI'},
#   {'id': '1495044610149728256',
#    'text': 'This where I’m at with it https://t.co/piawO6YN2f'},
#   {'id': '1495043272074485765',
#    'text': '@MicahAdams13 When you say pantheon, what do u mean?'},
#   {'id': '1495042851788496898',
#    'text': 'Are u born with any skills or talents?'},
#   {'id': '1495041712682586114',
#    'text': 'Is Legacy is more about your narrative than your actual performance?'},
#   {'id': '1494719520044429318', 'text': '🔥🔥🔥 https://t.co/C6LqHH75dO'},
#   {'id': '1494330592749518860',
#    'text': 'Thank you for setting a great example and playing the game with supreme skill @DeMar_DeRozan'},
#   {'id': '1494172788252418049',
#    'text': 'Every win counts my boy… https://t.co/N3iVH6RYud'},
#   {'id': '1494151527602270209', 'text': 'Way to lead us tonight 24…'},
#   {'id': '1494150836162904066',
#    'text': 'Nets fans were loud in the barc….I mean the garden tonight'},
#   {'id': '1494019254504599556',
#    'text': 'Wise words from a vc og on @boardroom https://t.co/47bYkD6xTW'},
#   {'id': '1493983317758259202',
#    'text': 'https://t.co/ho6mqRpbTY https://t.co/aCWjktxaX2'},
#   {'id': '1493935849179914243',
#    'text': 'RT @boardroom: BREAKING: Boardroom and @FanDuel have announced an exclusive partnership across web, video, audio, editorial, and social.\n\n@…'},
#   {'id': '1493691787550109701',
#    'text': 'That’s love god, I appreciate you… https://t.co/MEbBWrgkac'},
#   {'id': '1492265360959184911', 'text': '@CFish4eva Laugh a little'},
#   {'id': '1492161783276187649',
#    'text': 'RT @35Ventures: The NY "Call of Duty" team @Subliners are showing everyone a different side of esports. Watch the first episode of their ne…'},
#   {'id': '1491471846474199042',
#    'text': "we got a lot to discuss on this week's ETCS, lock in https://t.co/lPgJqu1Rll"},
#   {'id': '1490702124904235014',
#    'text': 'Great new campaign from @weedmaps ⬇️ https://t.co/8T68wW5Ae4'},
#   {'id': '1490679581774331904',
#    'text': '@WillHodges_ It’s weird that you’re playing bodyguard for stephen A. This wasn’t just for stephen A, it’s to everybody who wants to box my career into that narrative.'},
#   {'id': '1490676328638652417',
#    'text': '@WillHodges_ I just don’t believe my career will be defined by that, of course they will talk about it but I’m saying, my career is much more than that. If u didn’t understand what I was gettin at, it’s cuz u choose not to'},
#   {'id': '1490674793645056000', 'text': '@nyjetsgirl25 Just Ignore me please'},
#   {'id': '1490671691323875334', 'text': '@bwood_33 U SPITTIN!!!!'},
#   {'id': '1490357905043996673',
#    'text': '@NotoriousVIC007 Why do u care what I do?'},
#   {'id': '1490325717275578378', 'text': '@HIIMOTHY We? Who U speaking for?'},
#   {'id': '1490323178278768647',
#    'text': '@VJZ_3 @Harrison_Grimm That’s not my problem'},
#   {'id': '1490312925399195651',
#    'text': 'Steve, since u decided to use ESPN to push your personal agendas, im sure your minions will run with this story for you, but if u believe this is what my career is defined by then you just a flat out hater. It’s gonna be hard to box the god in https://t.co/AUMkP8P59g'},
#   {'id': '1489608815255465990', 'text': '@ESPNNBA @stephenasmith Egregious'},
#   {'id': '1489335759366725634',
#    'text': 'RT @nbatopshot: The Elite Queue is ALMOST here 👏\n\n@KDTrey5 Certified Elite packs, feat. a chance to pull a Limited Edition, Rare or Legenda…'},
#   {'id': '1488976454419369984',
#    'text': 'RT @richkleiman: Go time @kevinjsong'},
#   {'id': '1488904126444584964',
#    'text': "RT @nbatopshot: Kevin Durant's making HISTORY on Thursday as the 1st NBA player to curate Moment™ NFTs in a pack drop. 🔥\n\nFind all 6 of his…"},
#   {'id': '1488904077765496833',
#    'text': 'New @richkleiman @boardroom pod w the one and only @bubbawallace\xa0https://t.co/FWlhMtqOeh'},
#   {'id': '1488225924109774849',
#    'text': 'More on the pack and why we created it @boardroom:\xa0\xa0https://t.co/mhQYq7M0CU'},
#   {'id': '1488225920972374018',
#    'text': 'welcome to the first ever @NBATopShot Game Recognize Game pack: https://t.co/XAW3VIGyxO https://t.co/dXZEZtwHjP'},
#   {'id': '1487463754883387392',
#    'text': 'RT @boardroom: .@KDTrey5 loves what he\'s seeing from Joe Burrow &amp; Jamarr Chase. 🔥\n\n"He\'s bringing a couple back to Cincy before his time\'s…'},
#   {'id': '1487442222769491976',
#    'text': 'went in on the best NFL QBs, All Star, and more with\xa0@bansky on this weeks ETCs\xa0https://t.co/ZB5Q7lpFLF'},
#   {'id': '1486869634871607304',
#    'text': 'RT @boardroom: .@KDTrey5 is ready to reload.\n\n"Last year I thought I picked the best team in All-Star Game history, but we laid an egg when…'},
#   {'id': '1486374557338451975',
#    'text': 'RT @boardroom: “I’m feeling good, man,” KD said on this week’s episode of Boardroom’s #TheETCs podcast.\n\n“It stung for a couple of days but…'},
#   {'id': '1486374087928778759',
#    'text': "RT @boardroom: .@KDTrey5 + @bansky discuss KD's injury status and working his way back onto the court, + much more on an all-new #TheETCS.…"},
#   {'id': '1485701903082307588',
#    'text': 'RT @boardroom: BREAKING: The Brooklyn Nets have filed trademarks indicating they are looking to become the first NBA team to enter the meta…'},
#   {'id': '1484186466666307585',
#    'text': "this week's @boardroom OOO w/Aryeh Bourkoff is a good one\nhttps://t.co/WoRnEg3UyF"},
#   {'id': '1483900140972875786',
#    'text': 'RT @boardroom: An inside look at @NBATopShot helping @KDTrey5 buy his first Moment NFT. 👀\n\nGet your KD Starter Pack for new TopShot users h…'},
#   {'id': '1483900129992228868',
#    'text': 'RT @boardroom: .@DapperLabs’ @NBATopShot brings basketball fans around the world closer than ever to their favorite players and teams with…'},
#   {'id': '1483803519501099013',
#    'text': 'RT @nbatopshot: Join @KDTrey5 in the future of fandom 🔥\n\nGet a FREE Kevin Durant Moment™ NFT, hand-picked &amp; narrated by KD himself, when yo…'},
#   {'id': '1483788855757185026',
#    'text': "RT @boardroom: .@DapperLabs' new campaign featuring @KDTrey5 will run across TV, social &amp; digital platforms through July as the co. approac…"},
#   {'id': '1483788838661234692',
#    'text': 'RT @boardroom: BREAKING: @DapperLabs’ @NBATopShot has released its first-ever major national ad campaign.\n\nThe spot features fans of @KDTre…'},
#   {'id': '1483787258549481473',
#    'text': 'More on our new @nbatopshot spot and my KD starter pack now on @boardroom: https://t.co/0hBHi9jj38'}],
#  'meta': {'newest_id': '1512849149091274756',
#   'next_token': '7140dibdnow9c7btw3z452qo3huklw0oeikzdthz28qpf',
#   'oldest_id': '1483787258549481473',
#   'result_count': 100}}

# %%
tweets_dic = {"user_id": [], "tweet_id": [], "text": []}
for i in user_df["user_id"]:
  for j in get_tweets(i)["data"]:
    tweets_dic["user_id"].append(i)
    tweets_dic["tweet_id"].append(j["id"])
    tweets_dic["text"].append(j["text"])
    
tweets_df = pd.DataFrame(tweets_dic)
tweets_df
# Out:
#        user_id             tweet_id  \
# 0     35936474  1512849149091274756
# 1     35936474  1512658691207712774
# 2     35936474  1512647516008988675
# 3     35936474  1512471596291743744
# 4     35936474  1512155746615672844
# ...        ...                  ...
# 1195  43658360  1368028286291378178
# 1196  43658360  1364424143047774208
# 1197  43658360  1356793964226093058
# 1198  43658360  1355623039925248003
# 1199  43658360  1355622820055670784
#
#                                                    text
# 0     S/O Dwight Powell, made that Achilles recovery...
# 1                      U get it https://t.co/GycZwrnxfm
# 2                No foul??????? https://t.co/PBseqE2sEt
# 3                 @mustseetb_ @jj_redick Yep. The slots
# 4      Preciate dat dere boiiii https://t.co/9DJB56ZRa3
# ...                                                 ...
# 1195  Gets to a point where you just gotta laugh at ...
# 1196             Can’t help but think how fake it is...
# 1197  Congrats to my brotha Freddy V! Kyle old ass c...
# 1198  RT @brkicks: .@DeMar_DeRozan not playing fair\...
# 1199  RT @spurs: If you loved @DeMar_DeRozan's 'Fies...
#
# [1200 rows x 3 columns]

# %%
from google.colab import files
tweets_df.to_csv("user_tweets.csv", index=False)

files.download("user_tweets.csv")
